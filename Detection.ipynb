# %%
# !python yolov5/detect.py --weights best.pt --source 0
# Out:
# detect: weights=['best.pt'], source=0, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-6-11 Python-3.9.12 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 232 layers, 7451490 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 Done. (0.283s)
# 0: 480x640 Done. (0.302s)
# 0: 480x640 Done. (0.264s)
# 0: 480x640 Done. (0.274s)
# 0: 480x640 Done. (0.255s)
# 0: 480x640 Done. (0.266s)
# 0: 480x640 Done. (0.283s)
# 0: 480x640 Done. (0.292s)
# 0: 480x640 Done. (0.290s)
# 0: 480x640 Done. (0.271s)
# 0: 480x640 Done. (0.266s)
# 0: 480x640 Done. (0.281s)
# 0: 480x640 Done. (0.249s)
# ...

# %%
# !python yolov5/detect.py --weights best.pt --source Dataset/test/traffic-sign-to-test.mp4
# Out:
# detect: weights=['best4.pt'], source=Dataset/test/traffic-sign-to-test.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-6-11 Python-3.9.12 torch-1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7217794 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/56) C:\Users\Dell\Downloads\Compressed\Dataset\test\traffic-sign-to-test.mp4: 384x640 2 200ms, Done. (0.235s)
# video 1/1 (2/56) C:\Users\Dell\Downloads\Compressed\Dataset\test\traffic-sign-to-test.mp4: 384x640 2 200ms, Done. (0.188s)
# video 1/1 (3/56) C:\Users\Dell\Downloads\Compressed\Dataset\test\traffic-sign-to-test.mp4: 384x640 2 200ms, Done. (0.156s)
# ...

# %%
# !python yolov5/detect.py --source 0 --classes  9
# Out:
# detect: weights=yolov5\yolov5s.pt, source=0, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[9], agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-6-11 Python-3.9.12 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 Done. (0.266s)
# 0: 480x640 Done. (0.293s)
# 0: 480x640 Done. (0.247s)
# 0: 480x640 Done. (0.248s)
# 0: 480x640 Done. (0.238s)
# 0: 480x640 Done. (0.231s)
# 0: 480x640 Done. (0.215s)
# 0: 480x640 Done. (0.230s)
# 0: 480x640 Done. (0.216s)
# 0: 480x640 Done. (0.261s)
# 0: 480x640 Done. (0.270s)
# 0: 480x640 Done. (0.284s)
# ...

# %%
# !python yolov5/detect.py --source TrafficLight/datasets/coco128/image001.jpeg
# Out:
# detect: weights=yolov5\yolov5s.pt, source=TrafficLight/datasets/coco128/image001.jpeg, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-6-11 Python-3.9.12 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Traceback (most recent call last):
#   File "C:\Users\Dell\Downloads\Compressed\yolov5\detect.py", line 252, in <module>
#     main(opt)
#   File "C:\Users\Dell\Downloads\Compressed\yolov5\detect.py", line 247, in main
#     run(**vars(opt))
#   File "F:\prgm\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
# ...

# %%
# !python yolov5/detect.py --weights best9.pt --source 0
